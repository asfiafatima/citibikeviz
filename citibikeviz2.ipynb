# %%
#dependencies
import csv
import pandas as pd
import warnings
warnings.simplefilter("error")

# %%
db_1906 = pd.read_csv(r"C:\Users\thevc\OneDrive\Desktop\citibikeviz\201906-citibike-tripdata.csv")
db_1912 = pd.read_csv(r"C:\Users\thevc\OneDrive\Desktop\citibikeviz\201912-citibike-tripdata.csv")
db_2006 = pd.read_csv(r"C:\Users\thevc\OneDrive\Desktop\citibikeviz\202006-citibike-tripdata.csv")
db_2012 = pd.read_csv(r"C:\Users\thevc\OneDrive\Desktop\citibikeviz\202012-citibike-tripdata.csv")

# %%
citibikedata_19 = pd.concat([db_1906,db_1912])

# %%
citibikedata_19.isnull().any()
# Out:
# tripduration               False
# starttime                  False
# stoptime                   False
# start station id           False
# start station name         False
# start station latitude     False
# start station longitude    False
# end station id             False
# end station name           False
# end station latitude       False
# end station longitude      False
# bikeid                     False
# usertype                   False
# birth year                 False
# gender                     False
# dtype: bool

# %%
citibikedata_19.tail()
# Out:
#         tripduration                 starttime                  stoptime  \
# 955205            93  2019-12-31 23:58:18.0160  2019-12-31 23:59:51.6360
# 955206           786  2019-12-31 23:58:59.8960  2020-01-01 00:12:06.3460
# 955207           351  2019-12-31 23:59:03.6950  2020-01-01 00:04:54.8730
# 955208          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 955209           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#         start station id                start station name  \
# 955205              3141                   1 Ave & E 68 St
# 955206               490                   8 Ave & W 33 St
# 955207              3349  Grand Army Plaza & Plaza St West
# 955208               252      MacDougal St & Washington Sq
# 955209              3351                  E 102 St & 1 Ave
#
#         start station latitude  start station longitude  end station id  \
# 955205               40.765005               -73.958185            3142
# ...

# %%
citibikedata_final19=citibikedata_19.dropna(axis=0).reset_index(drop=True)
citibikedata_final19.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           330  2019-06-01 00:00:01.5000  2019-06-01 00:05:31.7600
# 1           830  2019-06-01 00:00:04.2400  2019-06-01 00:13:55.1470
# 2           380  2019-06-01 00:00:06.0190  2019-06-01 00:06:26.7790
# 3          1155  2019-06-01 00:00:06.7760  2019-06-01 00:19:22.5380
# 4          1055  2019-06-01 00:00:07.5200  2019-06-01 00:17:42.5580
#
#    start station id       start station name  start station latitude  \
# 0              3602           31 Ave & 34 St               40.763154
# 1              3054  Greene Ave & Throop Ave               40.689493
# 2               229           Great Jones St               40.727434
# 3              3771  McKibbin St & Bogart St               40.706237
# 4               441          E 52 St & 2 Ave               40.756014
#
#    start station longitude  end station id       end station name  \
# 0               -73.920827            3570         35 Ave & 37 St
# ...

# %%
citibikedata_final19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3080580 entries, 0 to 3080579
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         int64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           int64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 352.5+ MB

# %%
citibikedata_final19.to_csv("citibikeTripdata2019.csv",index=False)

# %%
citibikedata_20 = pd.concat([db_2006,db_2012])

# %%
citibikedata_20.isnull().any()
# Out:
# tripduration               False
# starttime                  False
# stoptime                   False
# start station id           False
# start station name         False
# start station latitude     False
# start station longitude    False
# end station id             False
# end station name           False
# end station latitude       False
# end station longitude      False
# bikeid                     False
# usertype                   False
# birth year                 False
# gender                     False
# dtype: bool

# %%
citibikedata_20.tail()
# Out:
#          tripduration                 starttime                  stoptime  \
# 1088924          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 1088925           288  2020-12-31 23:58:37.8400  2021-01-01 00:03:26.3250
# 1088926           152  2020-12-31 23:58:52.8090  2021-01-01 00:01:25.6720
# 1088927           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
# 1088928          2589  2020-12-31 23:59:57.4070  2021-01-01 00:43:06.4490
#
#          start station id                   start station name  \
# 1088924               526                      E 33 St & 5 Ave
# 1088925              3307               West End Ave & W 94 St
# 1088926              3510  Adam Clayton Powell Blvd & W 123 St
# 1088927              4073          W 51 St & Rockefeller Plaza
# 1088928              3581           Underhill Ave & Lincoln Pl
#
#          start station latitude  start station longitude  end station id  \
# ...

# %%
citibikedata_final20=citibikedata_20.dropna(axis=0).reset_index(drop=True)
citibikedata_final20.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1062  2020-06-01 00:00:03.3720  2020-06-01 00:17:46.2080
# 1          3810  2020-06-01 00:00:03.5530  2020-06-01 01:03:33.9360
# 2          1017  2020-06-01 00:00:09.6140  2020-06-01 00:17:06.8330
# 3           226  2020-06-01 00:00:12.1780  2020-06-01 00:03:58.8640
# 4          1437  2020-06-01 00:00:21.2550  2020-06-01 00:24:18.9650
#
#    start station id        start station name  start station latitude  \
# 0              3419       Douglass St & 4 Ave               40.679279
# 1               366  Clinton Ave & Myrtle Ave               40.693261
# 2               389       Broadway & Berry St               40.710446
# 3              3255           8 Ave & W 31 St               40.750585
# 4               367   E 53 St & Lexington Ave               40.758281
#
#    start station longitude  end station id             end station name  \
# ...

# %%
citibikedata_final20.to_csv("citibikeTripdata2020.csv",index=False)
